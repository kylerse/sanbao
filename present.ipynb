# %% [markdown]
# ### 性骚扰定义统计结果

# %%
fig, axs = plt.subplots(ncols=3,figsize=(15,4))
plt.tight_layout(w_pad=8)
axs[1].set_title('性骚扰定义理解\n')
sn.distplot(record[9],bins=5, hist = True, kde = False,rug=False,norm_hist=False,ax=axs[0],axlabel='总体')
sn.distplot(record[record[8]=='男'][9], bins=5, hist = True, color = 'b', kde = False,rug=False,norm_hist=False,ax=axs[1],axlabel='男性群体')
sn.distplot(record[record[8]=='女'][9], bins=5, hist = True, color = 'r', kde = False,rug=False,norm_hist=False,ax=axs[2],axlabel='女性群体')
for i in range(3):
    t = list(Answer9())
    axs[i].set_xticklabels(['',t[0],'',t[1],'',t[2]],rotation='10') 
    axs[i].set_ylabel('频次')

# %% [markdown]
# 如上图所示，大多数人认为性骚扰是骚扰一方有目的且令被骚扰一方感到不适的行为的,男女之间未有明显差异的，但是似乎男性群体更注意骚扰一方有目的的行为，女性群体选取令骚扰一方感到不适的选项相对而言更为多些。

# %% [markdown]
# ## 熟识程度影响情况

# %%
fig, axs = plt.subplots(ncols=3,figsize=(16,5))
plt.tight_layout(w_pad=4)
axs[1].set_title('他人性别及熟识程度对人感到性骚扰程度影响情况\n')
sn.distplot(record[12], hist = True, kde = False,rug=False,norm_hist=False,ax=axs[0],axlabel='完全陌生的同性')
sn.distplot(record[13], hist = True, kde = False,rug=False,norm_hist=False,ax=axs[1],axlabel='熟识的同性')
sn.distplot(record[14], hist = True, kde = False,rug=False,norm_hist=False,ax=axs[2],axlabel='异性(无论陌生熟识)')
for i in range(3):
    axs[i].set_xticklabels([0]+[Answer12_14()[j] for j in range(1,6)],rotation='30') 
    axs[i].set_ylabel('频次')

# %% [markdown]
# 由上图可以明显看出，熟识程度对于大家对性骚扰的认知是有明显影响的，大部分人可能更认为只是同性好友之间的亲密身体接触只打闹。

# %% [markdown]
# ##  男女性别差异情况分析

# %%
fig, axs = plt.subplots(ncols=3,figsize=(21,5))
axs[1].set_title('男女对比分析\n')
sn.distplot(record[record[8]=='男'][12], hist = True, color='b', hist_kws={"alpha": 0.3},kde = True,rug=False,norm_hist=False,ax=axs[0],axlabel='完全陌生的同性')
sn.distplot(record[record[8]=='女'][12], hist = True, color='r',hist_kws={"alpha": 0.3},kde = True,rug=False,norm_hist=False,ax=axs[0],axlabel='完全陌生的同性')
sn.distplot(record[record[8]=='男'][13], hist = True, color='b', hist_kws={"alpha": 0.3},kde = True,rug=False,norm_hist=False,ax=axs[1],axlabel='熟识的同性')
sn.distplot(record[record[8]=='女'][13], hist = True, color='r',hist_kws={"alpha": 0.3},kde = True,rug=False,norm_hist=False,ax=axs[1],axlabel='熟识的同性')
sn.distplot(record[record[8]=='男'][14], bins=9, hist = True, color='b', hist_kws={"alpha": 0.3},kde = True,rug=False,norm_hist=False,ax=axs[2],axlabel='异性(无论陌生熟识)')
sn.distplot(record[record[8]=='女'][14], bins=9, hist = True, color='r',hist_kws={"alpha": 0.3},kde = True,rug=False,norm_hist=False,ax=axs[2],axlabel='异性(无论陌生熟识)')

#axs[1].set_xticks([0,3,5,6,7])
for i in range(3):
    axs[i].set_xticklabels(["",""]+[Answer12_14()[j] for j in range(1,6)],rotation='30')

# %% [markdown]
# 可以看出, 在同性之间，对于性骚扰的态度分布，男女表现并没有很大的差异。而对于异性的态度却截然不同。有些男性觉得未经允许的亲密接触完全不会构成性骚扰，而这一比例在女性中几乎为零。，而非常大比例的女性选择的是很可能会和一定会。

# %% [markdown]
# ### 具体统计数据详情如下

# %%
GenderDif12_14
# Out:
#           完全不会  基本上不会  依严重程度而定  很可能会  一定会
# 陌生同性（总计）     9     72      114   164   66
# 熟识同性（总计）    50    178      104    70   23
# 异性（总计）      24     72       93   156   80
# 陌生同性（男性）     5     40       58    79   29
# 熟识同性（男性）    25     84       51    39   12
# 异性（男性）      23     43       58    67   20
# 陌生同性（女性）     5     40       58    79   29
# 熟识同性（女性）    25     94       53    31   11
# 异性（女性）       1     29       35    89   60

# %% [markdown]
# ## 男女生倾向相关性分析

# %%
x, y = record[record[8]=='男'],record[record[8]=='女']
fig, axs = plt.subplots(ncols=3,figsize=(18,5))
plt.tight_layout( w_pad=10)
#Cx = Counter(x)
axs[0].scatter(x[12].apply(lambda x:x+random.normalvariate(0,0.12)),x[13].apply(lambda x:x+random.normalvariate(0,0.12)),marker='o', color = 'b', linewidths=3, alpha= 0.1)
axs[0].scatter(y[12].apply(lambda x:x+random.normalvariate(0,0.12)),y[13].apply(lambda x:x+random.normalvariate(0,0.12)),marker='o', color = 'r',linewidths=3, alpha= 0.1)
axs[1].scatter(x[13].apply(lambda x:x+random.normalvariate(0,0.12)),x[14].apply(lambda x:x+random.normalvariate(0,0.12)),marker='o', color = 'b', linewidths=3, alpha= 0.1)
axs[1].scatter(x[13].apply(lambda x:x+random.normalvariate(0,0.12)),x[14].apply(lambda x:x+random.normalvariate(0,0.12)),marker='o', color = 'r', linewidths=3, alpha= 0.1)
axs[2].scatter(x[12].apply(lambda x:x+random.normalvariate(0,0.12)),x[14].apply(lambda x:x+random.normalvariate(0,0.12)),marker='o', color = 'b', linewidths=3, alpha= 0.1)
axs[2].scatter(x[12].apply(lambda x:x+random.normalvariate(0,0.12)),x[14].apply(lambda x:x+random.normalvariate(0,0.12)),marker='o', color = 'r', linewidths=3, alpha= 0.1)
for i in range(3):
    axs[i].set_xticklabels([0]+[Answer12_14()[j] for j in range(1,6)],rotation='50')
    axs[i].set_yticklabels([0]+[Answer12_14()[j] for j in range(1,6)],rotation='50')

#plt.rc('axes', labelsize=MEDIUM_SIZE)
axs[0].set_xlabel('完全陌生的同性')
axs[0].set_ylabel('熟识的同性')
axs[1].set_xlabel('熟识的同性')
axs[1].set_ylabel('异性')
axs[2].set_xlabel('完全陌生的同性')
axs[2].set_ylabel('异性')
print('')

# %% [markdown]
# 其中蓝色点代表男生，红色点代表女生

# %%
x, y = record[12],record[13]
with sn.axes_style("white"):
    sn.jointplot(x=x, y=y, kind="kde").set_axis_labels("完全陌生的同性", "熟识的同性");

# %% [markdown]
# 没什么非常明显的相关。密度最大的（4，2）点是（完全陌生同性很可能觉得性骚扰，熟识的同性基本不会觉得性骚扰）

# %%
x, y = record[12],record[14]
with sn.axes_style("white"):
    sn.jointplot(x=x, y=y, kind="kde").set_axis_labels("完全陌生的同性", "异性");

# %% [markdown]
# 都比较negative,最浓的点是意味着都很可能觉得是性骚扰。

# %%
x, y = record[13],record[14]
with sn.axes_style("white"):
    sn.jointplot(x=x, y=y, kind="kde").set_axis_labels("熟识的同性", "异性");

# %% [markdown]
# ### 遭到性骚扰会怎么办？

# %%
fig, axs = plt.subplots(ncols=2,figsize=(21,5))
#axs[1].set_title('男女对比分析\n')
sn.distplot(record[11], hist = True, bins=7, color='r', hist_kws={"alpha": 0.3},kde = True,rug=False,norm_hist=False,ax=axs[0],axlabel='反应措施统计')

sn.distplot(record[record[8]=='女'][11], hist = True, bins=7, color='r', hist_kws={"alpha": 0.3},kde = True,rug=False,norm_hist=False,ax=axs[1])
sn.distplot(record[record[8]=='男'][11], hist = True, bins=7, color='b',hist_kws={"alpha": 0.3},kde = True,rug=False,norm_hist=False,ax=axs[1],axlabel='男女情况对比')

#axs[1].set_xticks([0,3,5,6,7])
for i in range(2):
    t = Answer11()
    axs[i].set_xticklabels(['','',t[1],t[2],t[3],t[4],''],rotation='30')

# %% [markdown]
# 一个很有意思的点，反而更多的女性是会选择当场揭穿对方并向周围人求救，可能是女性内心对于这种反击的需求或者渴望更为强烈。

# %% [markdown]
# ### 对于性侵受害者态度

# %%
fig, axs = plt.subplots(ncols=2,figsize=(23,5))
#axs[1].set_title('男女对比分析\n')
sn.distplot(record[15], hist = True, bins=9, color='r', hist_kws={"alpha": 0.3},kde = True,rug=False,norm_hist=False,ax=axs[0],axlabel='反应措施统计')
sn.distplot(record[record[8]=='女'][15], hist = True, bins=9, color='r', hist_kws={"alpha": 0.3},kde = True,rug=False,norm_hist=False,ax=axs[1])
sn.distplot(record[record[8]=='男'][15], hist = True, bins=9, color='b',hist_kws={"alpha": 0.3},kde = True,rug=False,norm_hist=False,ax=axs[1],axlabel='男女情况对比')


t = Answer15()
axs[0].set_xticklabels(['',t[1],t[2],t[3],t[4],t[5]],rotation='30') 
axs[1].set_xticklabels(['','',t[1],t[2],t[3],t[4],t[5]],rotation='30')
print('')

# %% [markdown]
# 男女性态度无显著差别

# %% [markdown]
# ### 性骚扰的判定中哪些方面存在双重标准

# %%
for keyword in ['颜值','财富','性别','不认为存在','其他']:
    record[keyword] = record[10].str.contains(keyword).apply(lambda x:[False,True].index(x))
subtable = record[['颜值','财富','性别','不认为存在','其他']]

# %% [markdown]
# #### 描述性统计

# %%
subtable.describe()
# Out:
#                颜值          财富          性别       不认为存在          其他
# count  425.000000  425.000000  425.000000  425.000000  425.000000
# mean     0.583529    0.181176    0.684706    0.188235    0.047059
# std      0.493554    0.385618    0.465180    0.391361    0.212014
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    0.000000    1.000000    0.000000    0.000000
# 75%      1.000000    0.000000    1.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000

# %% [markdown]
# 可以看出，大部分人还是认为一些双重标准是存在的，尤其性别和颜值上超过半数都认为是存在双重标准的。

# %% [markdown]
# ### 男女性对于双重标准的态度情况

# %%
subtable[record[8]=='男'].describe()
# Out:
#                颜值          财富          性别       不认为存在          其他
# count  211.000000  211.000000  211.000000  211.000000  211.000000
# mean     0.644550    0.213270    0.715640    0.165877    0.037915
# std      0.479788    0.410591    0.452182    0.372855    0.191444
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    0.000000    1.000000    0.000000    0.000000
# 75%      1.000000    0.000000    1.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000

# %%
subtable[record[8]=='女'].describe()
# Out:
#                颜值          财富          性别       不认为存在          其他
# count  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     0.523364    0.149533    0.654206    0.210280    0.056075
# std      0.500625    0.357449    0.476742    0.408463    0.230605
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    0.000000    1.000000    0.000000    0.000000
# 75%      1.000000    0.000000    1.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000

# %% [markdown]
# 仿佛是男性更认为性骚扰中存在各种程度的双标，在颜值、财富、性别等标准上认为存在双标的比例都显著大于女性。

# %% [markdown]
# #### 柱状图结果

# %%
fig, axs = plt.subplots(figsize=(10,5))
x = [1,2,3,4,5]
woman = [0.523364,0.149533,0.654206,0.210280,0.056075]
man = [0.644550,0.213270,0.715640,0.165877,0.037915]
total = [0.583529,0.181176,0.684706,0.188235,0.047059]

axs.bar([i- 0.2 for i in x], total,width=0.2,color='grey',align='center',label = '总体')
axs.bar(x, man,width=0.2,color='blue',align='center',label = '男性')
axs.bar([i+ 0.2 for i in x], woman,width=0.2,color='red',align='center',label = '女性')
axs.set_xticklabels([""]+list(subtable.columns))
plt.legend()
axs.set_ylabel('百分比')
axs.set_xlabel('各类标准')
# Out:
# Text(0.5,0,'各类标准')

# %% [markdown]
# ### 问卷调查者信息统计

# %%
a = Counter(record[7])
fig, axs = plt.subplots(figsize=(15,5))
facultyData = pd.DataFrame(a,index=['收集份数'])
axs.bar(a.keys(),a.values(),width=0.51,color='green',align='center',label = '总体')
axs.set_xlabel('院系分布')
axs.set_ylabel('频次')
facultyData.transpose()
# Out:
#     收集份数
# 经院    12
# 中文    59
# 元培    52
# 医学    23
# 经管    14
# 心理     7
# 哲学     2
# 社科     7
# 数学    11
# 生科    11
# 信管    16
# 信科    87
# 艺术     3
# 历史    11
# 法学    17
# 外院     8
# 政管     3
# 地空     6
# 城环    10
# 国关     6
# 物理    18
# 其他     8
# 教育    12
# 工学    10
# 新传     7
# 化学     4
# 考古     1

# %%
def faculty_class(f):
    if f in ['经院','经管']:
        return '经管学部'
    elif f in ['中文','艺术', '历史', '考古','外院','哲学']:
        return '人文学部'
    elif f in ['社科','法学','信管', '教育', '新传','政管','国关']:
        return '社科学部'
    elif f in ['心理', '数学', '生科','地空', '城环', '物理', '化学']:
        return '理学部'
    elif f in ['信科','工学']:
        return '信息与工程学部'
    elif f in ['医学']:
        return '医学部'
    return '跨学科及其他'
a = Counter(record[7].apply(faculty_class))
facultyGroup = pd.DataFrame(a,index=['收集份数'])
# Pie chart
labels = a.keys()
sizes = a.values()
#colors
colors = sorted(['#ffff99','#66b3ff','#ffcc99','#ff9999','#99ff99','#9999ff','#99ffff'])

#explode = (0.01,0.05,0.05,0.05,0.05,0.05)
fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)#,explode = explode)
#draw circle
centre_circle = plt.Circle((0,0),0.60,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
a = Counter(record[6])
gradeData = pd.DataFrame(a,index=['收集份数'])
fig, axs = plt.subplots(figsize=(10,5))
gradeCount = {'大一':250,'大二':46,'大三':69,'大四':15,'硕士':41,'博士':4}
cat = [ '大一', '大二', '大三','大四', '研一', '研二', '研三', '博一', '博二', '博三']
axs.bar(cat, [a[i] for i in cat],width=0.31,color='green',align='center',label = '总体')
axs.set_xlabel('院系分布')
axs.set_ylabel('频次')
gradeData.transpose()
# Out:
#     收集份数
# 大四    15
# 大一   250
# 大二    46
# 大三    69
# 研二    15
# 研一    19
# 研三     7
# 博一     2
# 博二     1
# 博三     1

# %%
# Pie chart
labels = gradeCount.keys()
sizes = gradeCount.values()
#colors
colors = sorted(['#ffff99','#ffcc99','#ff9999','#99ff99','#9999ff','#99ffff'])
#explode = (0.01,0.05,0.05,0.05,0.05,0.05)
fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)#,explode = explode)
#draw circle
centre_circle = plt.Circle((0,0),0.60,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()
